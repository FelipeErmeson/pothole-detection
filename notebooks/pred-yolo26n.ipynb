# %%
from pathlib import Path
import sys

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.23 🚀 Python-3.10.20 torch-2.10.0+cu128 CPU (13th Gen Intel Core i7-13650HX)
# Setup complete ✅ (20 CPUs, 15.3 GB RAM, 150.6/936.8 GB disk)
# /home/felipe/miniconda3/envs/pothole-detection/lib/python3.10/site-packages/torch/cuda/__init__.py:184: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
import albumentations as A
from ultralytics import YOLO

from ultralytics import settings
settings.update({"mlflow": True})

# %%
model = YOLO("yolo26n.pt")
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
model_with_finetuning = YOLO("runs/detect/yolo26_projeto_pothole/experimento_15/weights/best.pt")

# %%
results = model.predict(source='../data/Pothole.v1-raw.yolo26/train/images/img-117_jpg.rf.56a7e3b29e60b28e25b3f4a3c7817605.jpg', save=True, conf=0.5)

for result in results:
    boxes = result.boxes
    print(boxes)
# Out:
# image 1/1 /home/felipe/Documentos/Projetos/pothole-detection/notebooks/../data/Pothole.v1-raw.yolo26/train/images/img-117_jpg.rf.56a7e3b29e60b28e25b3f4a3c7817605.jpg: 640x640 (no detections), 91.8ms
# Speed: 2.8ms preprocess, 91.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /home/felipe/Documentos/Projetos/pothole-detection/notebooks/runs/detect/predict
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (720, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))

# %%
results = model.predict(source='../data/Pothole.v1-raw.yolo26/test/images/img-634_jpg.rf.42d6e4ebdda859ab935130b75ae5808f.jpg', save=True, conf=0.5)

for result in results:
    boxes = result.boxes
    print(boxes)
# Out:
# image 1/1 /home/felipe/Documentos/Projetos/pothole-detection/notebooks/../data/Pothole.v1-raw.yolo26/test/images/img-634_jpg.rf.42d6e4ebdda859ab935130b75ae5808f.jpg: 448x640 (no detections), 57.2ms
# Speed: 3.0ms preprocess, 57.2ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /home/felipe/Documentos/Projetos/pothole-detection/notebooks/runs/detect/predict
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (300, 450)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))

# %%
results = model_with_finetuning.predict(source='../data/Pothole.v1-raw.yolo26/train/images/img-117_jpg.rf.56a7e3b29e60b28e25b3f4a3c7817605.jpg', save=True, conf=0.5)

for result in results:
    boxes = result.boxes
    print(boxes)
# Out:
# image 1/1 /home/felipe/Documentos/Projetos/pothole-detection/notebooks/../data/Pothole.v1-raw.yolo26/train/images/img-117_jpg.rf.56a7e3b29e60b28e25b3f4a3c7817605.jpg: 640x640 2 potholes, 61.8ms
# Speed: 3.1ms preprocess, 61.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /home/felipe/Documentos/Projetos/pothole-detection/notebooks/runs/detect/predict2
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0.])
# conf: tensor([0.5827, 0.5708])
# data: tensor([[270.3170,  48.2325, 373.5422,  84.8905,   0.5827,   0.0000],
#         [263.0866, 273.7592, 410.4032, 501.3320,   0.5708,   0.0000]])
# id: None
# is_track: False
# orig_shape: (720, 720)
# shape: torch.Size([2, 6])
# xywh: tensor([[321.9296,  66.5615, 103.2252,  36.6580],
#         [336.7449, 387.5456, 147.3166, 227.5728]])
# xywhn: tensor([[0.4471, 0.0924, 0.1434, 0.0509],
#         [0.4677, 0.5383, 0.2046, 0.3161]])
# ...

# %%
results = model_with_finetuning.predict(source='../data/Pothole.v1-raw.yolo26/test/images/img-634_jpg.rf.42d6e4ebdda859ab935130b75ae5808f.jpg', save=True, conf=0.5)

print('results')
for result in results:
    boxes = result.boxes
    print(boxes)
# Out:
# image 1/1 /home/felipe/Documentos/Projetos/pothole-detection/notebooks/../data/Pothole.v1-raw.yolo26/test/images/img-634_jpg.rf.42d6e4ebdda859ab935130b75ae5808f.jpg: 448x640 4 potholes, 35.0ms
# Speed: 1.2ms preprocess, 35.0ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /home/felipe/Documentos/Projetos/pothole-detection/notebooks/runs/detect/predict2
# results
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0., 0., 0.])
# conf: tensor([0.8487, 0.8209, 0.5979, 0.5799])
# data: tensor([[210.6621,  77.7490, 249.9421,  98.9113,   0.8487,   0.0000],
#         [317.3085, 168.1593, 347.0002, 202.4342,   0.8209,   0.0000],
#         [252.4958,  56.5858, 277.2418,  69.8387,   0.5979,   0.0000],
#         [301.9189, 100.9634, 318.1854, 114.8603,   0.5799,   0.0000]])
# id: None
# is_track: False
# orig_shape: (300, 450)
# shape: torch.Size([4, 6])
# xywh: tensor([[230.3021,  88.3302,  39.2801,  21.1623],
# ...

# %%
results[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0., 0., 0.])
# conf: tensor([0.8487, 0.8209, 0.5979, 0.5799])
# data: tensor([[210.6621,  77.7490, 249.9421,  98.9113,   0.8487,   0.0000],
#         [317.3085, 168.1593, 347.0002, 202.4342,   0.8209,   0.0000],
#         [252.4958,  56.5858, 277.2418,  69.8387,   0.5979,   0.0000],
#         [301.9189, 100.9634, 318.1854, 114.8603,   0.5799,   0.0000]])
# id: None
# is_track: False
# orig_shape: (300, 450)
# shape: torch.Size([4, 6])
# xywh: tensor([[230.3021,  88.3302,  39.2801,  21.1623],
#         [332.1543, 185.2968,  29.6917,  34.2749],
#         [264.8688,  63.2123,  24.7460,  13.2529],
#         [310.0522, 107.9118,  16.2665,  13.8969]])
# xywhn: tensor([[0.5118, 0.2944, 0.0873, 0.0705],
#         [0.7381, 0.6177, 0.0660, 0.1142],
#         [0.5886, 0.2107, 0.0550, 0.0442],
#         [0.6890, 0.3597, 0.0361, 0.0463]])
# xyxy: tensor([[210.6621,  77.7490, 249.9421,  98.9113],
# ...

# %%
print(model.names)
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'micr
# ...

# %%
model_with_finetuning.names
# Out:
# {0: 'pothole'}
